# %% [markdown]
# **CARGA DE DATOS**
#
# ---
#
#
#
# Descarga el archivo de datos house_prices.csv que contiene las siguientes columnas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = 'https://docs.google.com/spreadsheets/d/1j_BQDhz-X29smvd0WkI6KP1klG7-lBfBHnzcQQprL8Y/pub?output=csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0     1  114300  1790         2          2       2    No         East
# 1     2  114200  2030         4          2       3    No         East
# 2     3  114800  1740         3          2       1    No         East
# 3     4   94700  1980         3          2       3    No         East
# 4     5  119800  2130         3          3       3    No         East

# %% [markdown]
# **EXPLORACION DE DATOS**
#
# ---
#
#
#  Realiza un análisis exploratorio de los datos para entender su estructura y detectar posibles problemas como valores nulos o outliers.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Home          128 non-null    int64
#  1   Price         128 non-null    int64
#  2   SqFt          128 non-null    int64
#  3   Bedrooms      128 non-null    int64
#  4   Bathrooms     128 non-null    int64
#  5   Offers        128 non-null    int64
#  6   Brick         128 non-null    object
#  7   Neighborhood  128 non-null    object
# dtypes: int64(6), object(2)
# memory usage: 8.1+ KB

# %%
df.describe()
# Out:
#              Home          Price         SqFt    Bedrooms   Bathrooms  \
# count  128.000000     128.000000   128.000000  128.000000  128.000000
# mean    64.500000  130427.343750  2000.937500    3.023438    2.445312
# std     37.094474   26868.770371   211.572431    0.725951    0.514492
# min      1.000000   69100.000000  1450.000000    2.000000    2.000000
# 25%     32.750000  111325.000000  1880.000000    3.000000    2.000000
# 50%     64.500000  125950.000000  2000.000000    3.000000    2.000000
# 75%     96.250000  148250.000000  2140.000000    3.000000    3.000000
# max    128.000000  211200.000000  2590.000000    5.000000    4.000000
#
#            Offers
# count  128.000000
# mean     2.578125
# std      1.069324
# min      1.000000
# 25%      2.000000
# 50%      3.000000
# 75%      3.000000
# max      6.000000

# %%
df['Neighborhood'].unique()
# Out:
# array(['East', 'North', 'West'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Home            0
# Price           0
# SqFt            0
# Bedrooms        0
# Bathrooms       0
# Offers          0
# Brick           0
# Neighborhood    0
# dtype: int64

# %%
#GRSAFICAR CORRELACIONES
import seaborn as sns
corr = df.select_dtypes(include=['int64', 'float64'])
corr = corr.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Se observa una relacion DP entre
#
#       -Price con SqFt, Bedrooms, Bathrooms

# %%
plt.scatter(corr['Price'], corr['SqFt'])
plt.show()

# %%
df['Neighborhood'].unique()
# Out:
# array(['East', 'North', 'West'], dtype=object)

# %% [markdown]
# **CONCLUSION**
#
# Se observa cierta correlacion entre los datos, pero no en todos que nos es su mayoria, por ese motivo se consideraria apropiado aplicar un MODELO DE REGRESION,
# Primero haria un lazypredict para escoger entre los mejores modelos para poder predecir los valores de la casa a traves de sus caracteristicas establecida
